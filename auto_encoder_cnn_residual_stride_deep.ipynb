# %% [markdown]
# # Auto Encoder

# %% [markdown]
# ## Load Dataset

# %%
DATASET_NAME = 'dataset-5000'
TEST_DATASET_NAME = 'dataset-test'
BATCH_SIZE = 16
MODEL_PATH = 'model/cnn_residual_stride_deep'

import os
import torch
import torch.nn as nn
import torchvision.transforms as transforms

from torch.utils.data import DataLoader
from util import GeneratedDataset

trainset = GeneratedDataset(DATASET_NAME, transforms.ToTensor())
trainloader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)

testset = GeneratedDataset(TEST_DATASET_NAME, transforms.ToTensor())
testloader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'

if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %% [markdown]
# ## Define CNN based auto-encoder
#
# - 64 * 64 * 3 image input = 12,288
# - Cov3 with 32 channel, 3 * 3 * 3 * 32 = 864 parameters
# - ReLU
# - MaxPool -> 32 * 32 * 32 hidden state = 32768
# - Cov3 with 64 channel, 32 * 3 * 3 * 64 = 18432 parameters
# - ReLU
# - MaxPool -> 16 * 16 * 64 hidden state = 16384
# - Cov3 with 128 channel, 64 * 3 * 3 * 128 = 73728 parameters
# - ReLU
# - MaxPool -> 8 * 8 * 128 = 8192 hidden state
# - Full connected 8192 -> **embedding size**
#
# And the decoder works reversely.

# %%
# Define the residual block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        if in_channels != out_channels or stride != 1:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride)
        else:
            self.shortcut = None

    def forward(self, x):
        residual = self.shortcut(x) if self.shortcut is not None else x
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x += residual
        return x

# Define the autoencoder model
class Autoencoder(nn.Module):
    def __init__(self, embedding_size=32, dropout_rate=0.25):
        super(Autoencoder, self).__init__()
        self.embedding_size = embedding_size

        # Encoder
        self.encoder = nn.Sequential(
            ResidualBlock(3, 32, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 64, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 128, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 128),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 128),
            nn.Dropout(dropout_rate)
        )
        self.fc1 = nn.Linear(8 * 8 * 128, embedding_size)  # Fully connected layer to get 32-length embedding

        # Decoder
        self.fc2 = nn.Linear(embedding_size, 8 * 8 * 128)  # Fully connected layer to reshape back to 8x8x128
        self.decoder = nn.Sequential(
            ResidualBlock(128, 128),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 64),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 32),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            nn.Conv2d(32, 3, kernel_size=3, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        encoded = encoded.view(encoded.size(0), -1)  # Flatten the tensor
        encoded = self.fc1(encoded)  # Get the embedding
        decoded = self.fc2(encoded)  # Reshape back to 8x8x128
        decoded = decoded.view(decoded.size(0), 128, 8, 8)
        decoded = self.decoder(decoded)
        return decoded, encoded

# %%
from util import calc_and_plot_metrics, fit_nearest_neighbor, train_model_steps, plot_model, count_parameters, save_to_file, load_from_file

def train_model(embedding_size=32, dropout_rate=0.25, learning_rate=1e-4, weight_decay=1e-5, num_epochs=50):
    # Initialize the model
    model = Autoencoder(embedding_size=embedding_size, dropout_rate=dropout_rate)
    print(f'Number of parameters: {count_parameters(model)}')

    model_path = f'{MODEL_PATH}/e{embedding_size}.pth'
    stat_path = f'{MODEL_PATH}/e{embedding_size}.pkl'
    if os.path.exists(model_path) and os.path.exists(stat_path):
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        train_losses, test_losses = load_from_file(stat_path)
    else:
        model, train_losses, test_losses = train_model_steps(model, trainloader, testloader, learning_rate, weight_decay, num_epochs)
        # Save the model
        torch.save(model.state_dict(), model_path)
        save_to_file((train_losses, test_losses), stat_path)

    fit_nearest_neighbor(model)
    calc_and_plot_metrics(model, testset)
    plot_model(model, train_losses, test_losses, testset)
    return model, train_losses, test_losses

# %% [markdown]
# ## Evaluation
#
# Testing with embedding size of (down from 8192)
# - 4
# - 8
# - 16
# - 32
# - 64

# %%
train_model(embedding_size=4, dropout_rate=0.1)
# Out:
# Number of parameters: 1683495
# /Users/criyle/project/cse5524/cse5524final/util.py:323: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_embeddings = torch.tensor(train_embeddings)
# /Users/criyle/project/cse5524/cse5524final/util.py:324: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_embeddings = torch.tensor(test_embeddings)
# Color Accuracy: 0.303
# Shape Accuracy: 0.729
# Combined Accuracy: 0.217
# Silhouette Score: -0.19179904460906982
# Cluster Purity: 0.173
# Normalized Mutual Information (NMI): 0.22488840801538454
# Silhouette Score: -0.15606243908405304
# Cluster Purity: 0.214
# Normalized Mutual Information (NMI): 0.08255107963700738
# Silhouette Score: 0.016800178214907646
# Cluster Purity: 0.397
# Normalized Mutual Information (NMI): 0.05391867778096793
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=4, bias=True)
#    (fc2): Linear(in_features=4, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.22193531699169178,
#   0.14603841530914885,
#   0.1381784735110621,
#   0.13164513132061822,
#   0.127422423634571,
#   0.12422254755378911,
#   0.11972340386801253,
#   0.11703941461662896,
#   0.11495122570580187,
#   0.11328185356843967,
#   0.11163087165393769,
#   0.11078903901453216,
#   0.10989553312333628,
#   0.10800785328538273,
#   0.10817965315268062,
#   0.10538353315129066,
#   0.11030539851219129,
#   0.11068799694220478,
#   0.10791951984452744,
#   0.106368483314975,
#   0.10505504625293012,
#   0.10325792360420044,
#   0.1027385421787588,
#   0.10139439125268604,
#   0.10068670307961516,
#   0.09999021669974723,
#   0.0997849350777297,
#   0.09935312945479022,
#   0.09885869145440979,
#   0.0986911633406013,
#   0.09856261734288341,
#   0.09856428926031048,
#   0.09777709758415008,
#   0.09729382674248455,
#   0.09678525353868167,
#   0.0970755656734823,
#   0.09663231312609709,
#   0.09631263085019093,
#   0.09628990246131779,
#   0.0961047642694685,
#   0.09580722435737571,
#   0.0957222729921341,
#   0.09556931902330143,
#   0.0956364787234285,
#   0.09552016079473419,
#   0.09540778541336425,
#   0.0953427747772715,
#   0.09529933982049696,
#   0.09524738081632711,
#   0.09529696095484895],
#  [0.1605528775188658,
#   0.14458240816990534,
#   0.1375794435540835,
#   0.13397726759551062,
#   0.13027462422374694,
#   0.12928103631924068,
#   0.120876982098534,
#   0.12217029550718883,
#   0.11818854238778825,
#   0.12146883729904417,
#   0.11693216919425935,
#   0.11468896589108876,
#   0.11143776857190663,
#   0.10952697777085835,
#   0.10801461380389002,
#   0.10813992233976485,
#   0.1165704114569558,
#   0.11168481799818221,
#   0.10941883365786265,
#   0.10882713834917734,
#   0.1061134577861854,
#   0.10542930638979352,
#   0.10857112126217948,
#   0.10285753064921924,
#   0.10728871650875561,
#   0.10183443093583697,
#   0.10227918163651512,
#   0.102009612298201,
#   0.10225372501308956,
#   0.10130904845538594,
#   0.10045993316268163,
#   0.10219612173617833,
#   0.09981291208948408,
#   0.10014188124073876,
#   0.09878669105588443,
#   0.10174729089651789,
#   0.10027469523132794,
#   0.09998387506320364,
#   0.09841594756359145,
#   0.098525737249662,
#   0.0993356882698006,
#   0.09860861549774806,
#   0.09864718993268316,
#   0.09834182569904933,
#   0.09803665003606252,
#   0.0985409730956668,
#   0.09816826939109773,
#   0.09821094684894123,
#   0.09822377899572962,
#   0.09826632441272812])

# %%
train_model(embedding_size=8, dropout_rate=0.1)
# Out:
# Number of parameters: 1749035
# /Users/criyle/project/cse5524/cse5524final/util.py:323: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_embeddings = torch.tensor(train_embeddings)
# /Users/criyle/project/cse5524/cse5524final/util.py:324: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_embeddings = torch.tensor(test_embeddings)
# Color Accuracy: 0.319
# Shape Accuracy: 0.825
# Combined Accuracy: 0.259
# Silhouette Score: -0.15086504817008972
# Cluster Purity: 0.201
# Normalized Mutual Information (NMI): 0.25920580479007677
# Silhouette Score: -0.13009946048259735
# Cluster Purity: 0.207
# Normalized Mutual Information (NMI): 0.03966711768800436
# Silhouette Score: 0.028293486684560776
# Cluster Purity: 0.52
# Normalized Mutual Information (NMI): 0.18199936934906072
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=8, bias=True)
#    (fc2): Linear(in_features=8, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.2206041829559369,
#   0.14268665974989486,
#   0.131907550457377,
#   0.1169585199020922,
#   0.11132219884865963,
#   0.10691530707354743,
#   0.1039382331192303,
#   0.1016328698410965,
#   0.09869218003540374,
#   0.09679000578320826,
#   0.09516483658371261,
#   0.09435652547512953,
#   0.09329409353411236,
#   0.0917481223996074,
#   0.09139381026545652,
#   0.09078326377386864,
#   0.08977523760292858,
#   0.08884764999484483,
#   0.08817898985534049,
#   0.08756314809568012,
#   0.08719622423521246,
#   0.08821211680293845,
#   0.0859524981972699,
#   0.08516989737606277,
#   0.08497083788148511,
#   0.08428165234458714,
#   0.08380553169181934,
#   0.08322004813212937,
#   0.08318600641748014,
#   0.08253856981619478,
#   0.08274872343951521,
#   0.08186614432464392,
#   0.08158116466321122,
#   0.0813080304370711,
#   0.0810370188765823,
#   0.08076053670943735,
#   0.08048829150656922,
#   0.08030428333928029,
#   0.080063014746474,
#   0.0800017439566862,
#   0.07992993605831941,
#   0.07969220450368171,
#   0.07959134311388476,
#   0.07950701565740588,
#   0.07947436121467966,
#   0.07936048273223277,
#   0.07936859883058567,
#   0.07920371568479097,
#   0.07921857014298439,
#   0.07915267354240432],
#  [0.14829135213106398,
#   0.14124405478674268,
#   0.12094232924873867,
#   0.11190579843426508,
#   0.11044196772669988,
#   0.1066636268699926,
#   0.10222099277944792,
#   0.1032404996572979,
#   0.10152950953869593,
#   0.09939505751170809,
#   0.09431640212498014,
#   0.09265221874155695,
#   0.09239916556647845,
#   0.09240256835307394,
#   0.09129174922903378,
#   0.09208846606668972,
#   0.09020622464872542,
#   0.08988310237015996,
#   0.08841907014212912,
#   0.08961301829133715,
#   0.0904784147583303,
#   0.08866668025416041,
#   0.08735942231520774,
#   0.08694207715609717,
#   0.08531677196659739,
#   0.08564168433584864,
#   0.0852833426897488,
#   0.08447812414831585,
#   0.08335520191088555,
#   0.08396193006682018,
#   0.08353990594309474,
#   0.08305915959534191,
#   0.08302358106251746,
#   0.08293318529687231,
#   0.08213137557345723,
#   0.08266482851098454,
#   0.08192418202284783,
#   0.08162750977845419,
#   0.08103045537358239,
#   0.08130757256396233,
#   0.08153269108798769,
#   0.08098241574470959,
#   0.08118943119096378,
#   0.0807046660236896,
#   0.08074067036310832,
#   0.08052775399788978,
#   0.0806950344925835,
#   0.08049526071501156,
#   0.08049377917297303,
#   0.08050355220597888])

# %%
train_model(embedding_size=16, dropout_rate=0.1)
# Out:
# Number of parameters: 1880115
# /Users/criyle/project/cse5524/cse5524final/util.py:323: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_embeddings = torch.tensor(train_embeddings)
# /Users/criyle/project/cse5524/cse5524final/util.py:324: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_embeddings = torch.tensor(test_embeddings)
# Color Accuracy: 0.336
# Shape Accuracy: 0.884
# Combined Accuracy: 0.286
# Silhouette Score: -0.15697912871837616
# Cluster Purity: 0.194
# Normalized Mutual Information (NMI): 0.2522273122784324
# Silhouette Score: -0.13228870928287506
# Cluster Purity: 0.226
# Normalized Mutual Information (NMI): 0.046528388368971774
# Silhouette Score: 0.02881118468940258
# Cluster Purity: 0.542
# Normalized Mutual Information (NMI): 0.2100202776499079
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=16, bias=True)
#    (fc2): Linear(in_features=16, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.21352524817370758,
#   0.1396376447032054,
#   0.1296504688101074,
#   0.11247582933582818,
#   0.10505055400510184,
#   0.10134674950291554,
#   0.0973509239931457,
#   0.09267367335696952,
#   0.08888855462257093,
#   0.08701095820520632,
#   0.08492834192400162,
#   0.08320128891509943,
#   0.08230831297917869,
#   0.08120768039990157,
#   0.0802632456603713,
#   0.07934636602434106,
#   0.07862621098280714,
#   0.07834410567443592,
#   0.07822696536112898,
#   0.07687346863384825,
#   0.07658900290775222,
#   0.076048590837957,
#   0.0756696406454324,
#   0.07558463886380196,
#   0.07497287253602244,
#   0.07470838802929122,
#   0.07453469371500487,
#   0.07431136944090215,
#   0.07403583286669307,
#   0.07370119898940047,
#   0.07354485450651699,
#   0.07327939444980301,
#   0.07314068506272456,
#   0.0729102237989156,
#   0.0727931949229667,
#   0.07259151374046414,
#   0.07248564464406083,
#   0.07236043000802064,
#   0.07231504473680506,
#   0.07209422885657499,
#   0.07201287322960341,
#   0.07204491382066053,
#   0.07192598774838753,
#   0.07179380485567803,
#   0.07178341980559376,
#   0.07165947079230041,
#   0.0717231119021821,
#   0.07165726953849624,
#   0.07161328110831995,
#   0.07162169104043287],
#  [0.1474968403104752,
#   0.1362872797818411,
#   0.11891670596031916,
#   0.11012306040714658,
#   0.10371490224959358,
#   0.10154979155650215,
#   0.09875886319648652,
#   0.09089142616306033,
#   0.08811920443697581,
#   0.08598741374555088,
#   0.08517778440127297,
#   0.08310087226212971,
#   0.08226701451672448,
#   0.08215624502017385,
#   0.08010346844555839,
#   0.08050969036089049,
#   0.08020585349627904,
#   0.07938042779763539,
#   0.07837812839046357,
#   0.07783851423670375,
#   0.07901187010464214,
#   0.0766924037819817,
#   0.07669002332148098,
#   0.07617159909199155,
#   0.0757190196050538,
#   0.07647140743950057,
#   0.07613429634107484,
#   0.07482968661047164,
#   0.07615154934307886,
#   0.07537707781034803,
#   0.07470945310261515,
#   0.07489506971268427,
#   0.0741021041832273,
#   0.07435674888510553,
#   0.07465896459798964,
#   0.07381197159725522,
#   0.07432175699680571,
#   0.0741015144047283,
#   0.07371655396289295,
#   0.07377579879193079,
#   0.07356875531730198,
#   0.07359744159002153,
#   0.07326009023993735,
#   0.07317537743420828,
#   0.0731472818269616,
#   0.07328997635179096,
#   0.07304219103285245,
#   0.07306553186878326,
#   0.07307717470186097,
#   0.07306256766120593])

# %%
train_model(embedding_size=32, dropout_rate=0.1)
# Out:
# Number of parameters: 2142275
# /Users/criyle/project/cse5524/cse5524final/util.py:323: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_embeddings = torch.tensor(train_embeddings)
# /Users/criyle/project/cse5524/cse5524final/util.py:324: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_embeddings = torch.tensor(test_embeddings)
# Color Accuracy: 0.32
# Shape Accuracy: 0.859
# Combined Accuracy: 0.264
# Silhouette Score: -0.16851474344730377
# Cluster Purity: 0.203
# Normalized Mutual Information (NMI): 0.26156095713799427
# Silhouette Score: -0.14519570767879486
# Cluster Purity: 0.249
# Normalized Mutual Information (NMI): 0.08536695890643577
# Silhouette Score: 0.019349051639437675
# Cluster Purity: 0.527
# Normalized Mutual Information (NMI): 0.18992882690057264
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=32, bias=True)
#    (fc2): Linear(in_features=32, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.20880449268098075,
#   0.13528989564877347,
#   0.11560072045261487,
#   0.10559159714859515,
#   0.10032727420568086,
#   0.09612290218424874,
#   0.0900493651128615,
#   0.08592357661444158,
#   0.08299367228588357,
#   0.08187182380939825,
#   0.08050165700312621,
#   0.07941630502906852,
#   0.0787859361963912,
#   0.07801438269380945,
#   0.07720160466461136,
#   0.07665878381972877,
#   0.07644816622518884,
#   0.07571754310601436,
#   0.07533487953697912,
#   0.07495280414724502,
#   0.07462613236980316,
#   0.07411087849460089,
#   0.07387212966196834,
#   0.0736002907180748,
#   0.07338966758915791,
#   0.07311890561121721,
#   0.0728917122720339,
#   0.07262962760802466,
#   0.0722651929258348,
#   0.0722946234452077,
#   0.07201399907660179,
#   0.07182953261529294,
#   0.07168864754561227,
#   0.07152683795474399,
#   0.07142709614560246,
#   0.07135131110112888,
#   0.07108811418802594,
#   0.07097470078367395,
#   0.07096592242868183,
#   0.07079582819685387,
#   0.07073270339078416,
#   0.07063121622362838,
#   0.07057677367672371,
#   0.07056751934150918,
#   0.07056678056764526,
#   0.07054304075650514,
#   0.07046906541759214,
#   0.07055475148030173,
#   0.07039728331061217,
#   0.0704549776788908],
#  [0.14645630748025953,
#   0.12811720087414696,
#   0.10732791696985562,
#   0.10227408354717588,
#   0.09954972523781988,
#   0.09453800716806972,
#   0.08859451647315707,
#   0.0835989507299567,
#   0.08329601686388727,
#   0.08199330679480991,
#   0.08090702006741175,
#   0.07984244657887353,
#   0.07881702281652934,
#   0.07877088243526126,
#   0.07720334207018216,
#   0.07709205848357034,
#   0.07841010651891193,
#   0.07700502086016867,
#   0.07554053982335424,
#   0.0754542209444538,
#   0.07478152162262372,
#   0.07599988420094762,
#   0.07493348177226763,
#   0.07492353447846004,
#   0.0747022975295309,
#   0.07406305025021236,
#   0.07344529724546842,
#   0.07462490970889728,
#   0.07386327091427076,
#   0.07328707423238527,
#   0.07376609476549285,
#   0.07266385196929886,
#   0.07324948824114269,
#   0.07285139455445229,
#   0.07294500719696756,
#   0.07256353859390531,
#   0.07240330215011324,
#   0.07240709088860996,
#   0.07230535829587588,
#   0.07212308137899354,
#   0.07238049261153691,
#   0.07202208710331766,
#   0.0719601900449821,
#   0.07200506678412831,
#   0.07193639170792368,
#   0.07190441428905442,
#   0.07194035819598607,
#   0.07192285045508355,
#   0.07187862853918757,
#   0.07189134342802896])

# %%
train_model(embedding_size=64, dropout_rate=0.1)
# Out:
# Number of parameters: 2666595
# /Users/criyle/project/cse5524/cse5524final/util.py:323: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_embeddings = torch.tensor(train_embeddings)
# /Users/criyle/project/cse5524/cse5524final/util.py:324: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_embeddings = torch.tensor(test_embeddings)
# Color Accuracy: 0.285
# Shape Accuracy: 0.847
# Combined Accuracy: 0.233
# Silhouette Score: -0.17162561416625977
# Cluster Purity: 0.179
# Normalized Mutual Information (NMI): 0.24775623415913586
# Silhouette Score: -0.14753851294517517
# Cluster Purity: 0.234
# Normalized Mutual Information (NMI): 0.0595147674399484
# Silhouette Score: 0.00997943989932537
# Cluster Purity: 0.472
# Normalized Mutual Information (NMI): 0.1608801465363889
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=64, bias=True)
#    (fc2): Linear(in_features=64, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.19685523645184672,
#   0.12960273693925656,
#   0.1084509374448857,
#   0.09640558294880504,
#   0.08864427913730137,
#   0.08546667124707097,
#   0.08311638424095635,
#   0.08194353687353789,
#   0.08055223423404434,
#   0.07914917613751592,
#   0.07800985683505528,
#   0.07781159362425438,
#   0.07682293626113822,
#   0.0762724873547356,
#   0.07588531483952611,
#   0.07524741256532197,
#   0.07492352123506153,
#   0.07432972804045145,
#   0.07418064319620879,
#   0.07375982143103886,
#   0.07338221254535376,
#   0.07303132617863985,
#   0.07291467373553938,
#   0.07276877372885665,
#   0.07246113972018321,
#   0.07214839347063924,
#   0.07198566995775357,
#   0.07179559919590386,
#   0.07168847132033815,
#   0.0713448230498515,
#   0.07112374964851541,
#   0.07118594658355744,
#   0.07102806169908649,
#   0.07078917136493201,
#   0.07075472186786678,
#   0.07050917299982078,
#   0.07039023059816026,
#   0.07023439731317968,
#   0.07028433667442288,
#   0.07010860351351694,
#   0.07000109794945382,
#   0.07000700714060673,
#   0.06993264841814391,
#   0.06987149675433248,
#   0.06987366913416135,
#   0.06993172085656525,
#   0.06985987053987698,
#   0.0698483733061594,
#   0.06976450936862835,
#   0.06971004901650234],
#  [0.14040847737637777,
#   0.11216064873668882,
#   0.10384247132710048,
#   0.09273938184219693,
#   0.0866017925242583,
#   0.08296102983137918,
#   0.08098040899587056,
#   0.08383098150056506,
#   0.08190162107348442,
#   0.07807191762895811,
#   0.07829078523412583,
#   0.07808873938426139,
#   0.0765594525469674,
#   0.07719702657962603,
#   0.07678381158482461,
#   0.07519765878244052,
#   0.07622754153987718,
#   0.07650429306049196,
#   0.07448602674735917,
#   0.0755529733640807,
#   0.0750029194094832,
#   0.07373621450766685,
#   0.07419847702932736,
#   0.07423989468860248,
#   0.07363490943634321,
#   0.0733825716352652,
#   0.07302574233876334,
#   0.07342861214327434,
#   0.0724606816730802,
#   0.07312316299667435,
#   0.07249811729268422,
#   0.07245027947993506,
#   0.07226066486466498,
#   0.07226454525712937,
#   0.07210456083218257,
#   0.07171739549154327,
#   0.07166471669361704,
#   0.07155908845246785,
#   0.07171925979237707,
#   0.07185916442956243,
#   0.07133180594870023,
#   0.07139988982724765,
#   0.07119046636517086,
#   0.07125235845645268,
#   0.07121417754226261,
#   0.07119614412150686,
#   0.07123116492515519,
#   0.07114448268262166,
#   0.07119129456224896,
#   0.07116716934574975])
