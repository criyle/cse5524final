# %% [markdown]
# # Auto Encoder

# %% [markdown]
# ## Load Dataset

# %%
DATASET_NAME = 'dataset-5000'
TEST_DATASET_NAME = 'dataset-test'
BATCH_SIZE = 16
MODEL_PATH = 'model/cnn_residual_stride_deep'

import os
import torch
import torch.nn as nn
import torchvision.transforms as transforms

from torch.utils.data import DataLoader
from util import GeneratedDataset

trainset = GeneratedDataset(DATASET_NAME, transforms.ToTensor())
trainloader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)

testset = GeneratedDataset(TEST_DATASET_NAME, transforms.ToTensor())
testloader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'

if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %% [markdown]
# ## Define CNN based auto-encoder
#
# - 64 * 64 * 3 image input = 12,288
# - Cov3 with 32 channel, 3 * 3 * 3 * 32 = 864 parameters
# - ReLU
# - MaxPool -> 32 * 32 * 32 hidden state = 32768
# - Cov3 with 64 channel, 32 * 3 * 3 * 64 = 18432 parameters
# - ReLU
# - MaxPool -> 16 * 16 * 64 hidden state = 16384
# - Cov3 with 128 channel, 64 * 3 * 3 * 128 = 73728 parameters
# - ReLU
# - MaxPool -> 8 * 8 * 128 = 8192 hidden state
# - Full connected 8192 -> **embedding size**
#
# And the decoder works reversely.

# %%
# Define the residual block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        if in_channels != out_channels or stride != 1:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride)
        else:
            self.shortcut = None

    def forward(self, x):
        residual = self.shortcut(x) if self.shortcut is not None else x
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x += residual
        return x

# Define the autoencoder model
class Autoencoder(nn.Module):
    def __init__(self, embedding_size=32, dropout_rate=0.25):
        super(Autoencoder, self).__init__()
        self.embedding_size = embedding_size

        # Encoder
        self.encoder = nn.Sequential(
            ResidualBlock(3, 32, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 64, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 128, stride=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 128),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 128),
            nn.Dropout(dropout_rate)
        )
        self.fc1 = nn.Linear(8 * 8 * 128, embedding_size)  # Fully connected layer to get 32-length embedding

        # Decoder
        self.fc2 = nn.Linear(embedding_size, 8 * 8 * 128)  # Fully connected layer to reshape back to 8x8x128
        self.decoder = nn.Sequential(
            ResidualBlock(128, 128),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(128, 64),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 64),
            nn.Dropout(dropout_rate),
            ResidualBlock(64, 32),
            nn.Upsample(scale_factor=2),
            nn.Dropout(dropout_rate),
            ResidualBlock(32, 32),
            nn.Dropout(dropout_rate),
            nn.Conv2d(32, 3, kernel_size=3, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        encoded = encoded.view(encoded.size(0), -1)  # Flatten the tensor
        encoded = self.fc1(encoded)  # Get the embedding
        decoded = self.fc2(encoded)  # Reshape back to 8x8x128
        decoded = decoded.view(decoded.size(0), 128, 8, 8)
        decoded = self.decoder(decoded)
        return decoded, encoded

# %%
from util import calc_and_plot_metrics, train_model_steps, plot_model, count_parameters, save_to_file, load_from_file

def train_model(embedding_size=32, dropout_rate=0.25, learning_rate=1e-4, weight_decay=1e-5, num_epochs=50):
    # Initialize the model
    model = Autoencoder(embedding_size=embedding_size, dropout_rate=dropout_rate)
    print(f'Number of parameters: {count_parameters(model)}')

    model_path = f'{MODEL_PATH}/e{embedding_size}.pth'
    stat_path = f'{MODEL_PATH}/e{embedding_size}.pkl'
    if os.path.exists(model_path) and os.path.exists(stat_path):
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        train_losses, test_losses = load_from_file(stat_path)
    else:
        model, train_losses, test_losses = train_model_steps(model, trainloader, testloader, learning_rate, weight_decay, num_epochs)
        # Save the model
        torch.save(model.state_dict(), model_path)
        save_to_file((train_losses, test_losses), stat_path)

    calc_and_plot_metrics(model, testset)
    plot_model(model, train_losses, test_losses, testset)
    return model, train_losses, test_losses

# %% [markdown]
# ## Evaluation
#
# Testing with embedding size of (down from 8192)
# - 4
# - 8
# - 16
# - 32
# - 64

# %%
train_model(embedding_size=4, dropout_rate=0.1)
# Out:
# Number of parameters: 1683495
# Epoch [1/50], Train Loss: 0.2219, Test Loss: 0.1606
# Epoch [2/50], Train Loss: 0.1460, Test Loss: 0.1446
# Epoch [3/50], Train Loss: 0.1382, Test Loss: 0.1376
# Epoch [4/50], Train Loss: 0.1316, Test Loss: 0.1340
# Epoch [5/50], Train Loss: 0.1274, Test Loss: 0.1303
# Epoch [6/50], Train Loss: 0.1242, Test Loss: 0.1293
# Epoch [7/50], Train Loss: 0.1197, Test Loss: 0.1209
# Epoch [8/50], Train Loss: 0.1170, Test Loss: 0.1222
# Epoch [9/50], Train Loss: 0.1150, Test Loss: 0.1182
# Epoch [10/50], Train Loss: 0.1133, Test Loss: 0.1215
# Epoch [11/50], Train Loss: 0.1116, Test Loss: 0.1169
# Epoch [12/50], Train Loss: 0.1108, Test Loss: 0.1147
# Epoch [13/50], Train Loss: 0.1099, Test Loss: 0.1114
# Epoch [14/50], Train Loss: 0.1080, Test Loss: 0.1095
# Epoch [15/50], Train Loss: 0.1082, Test Loss: 0.1080
# Epoch [16/50], Train Loss: 0.1054, Test Loss: 0.1081
# Epoch [17/50], Train Loss: 0.1103, Test Loss: 0.1166
# Epoch [18/50], Train Loss: 0.1107, Test Loss: 0.1117
# Epoch [19/50], Train Loss: 0.1079, Test Loss: 0.1094
# Epoch [20/50], Train Loss: 0.1064, Test Loss: 0.1088
# Epoch [21/50], Train Loss: 0.1051, Test Loss: 0.1061
# Epoch [22/50], Train Loss: 0.1033, Test Loss: 0.1054
# Epoch [23/50], Train Loss: 0.1027, Test Loss: 0.1086
# Epoch [24/50], Train Loss: 0.1014, Test Loss: 0.1029
# Epoch [25/50], Train Loss: 0.1007, Test Loss: 0.1073
# Epoch [26/50], Train Loss: 0.1000, Test Loss: 0.1018
# Epoch [27/50], Train Loss: 0.0998, Test Loss: 0.1023
# Epoch [28/50], Train Loss: 0.0994, Test Loss: 0.1020
# Epoch [29/50], Train Loss: 0.0989, Test Loss: 0.1023
# Epoch [30/50], Train Loss: 0.0987, Test Loss: 0.1013
# Epoch [31/50], Train Loss: 0.0986, Test Loss: 0.1005
# Epoch [32/50], Train Loss: 0.0986, Test Loss: 0.1022
# Epoch [33/50], Train Loss: 0.0978, Test Loss: 0.0998
# Epoch [34/50], Train Loss: 0.0973, Test Loss: 0.1001
# Epoch [35/50], Train Loss: 0.0968, Test Loss: 0.0988
# Epoch [36/50], Train Loss: 0.0971, Test Loss: 0.1017
# Epoch [37/50], Train Loss: 0.0966, Test Loss: 0.1003
# Epoch [38/50], Train Loss: 0.0963, Test Loss: 0.1000
# Epoch [39/50], Train Loss: 0.0963, Test Loss: 0.0984
# Epoch [40/50], Train Loss: 0.0961, Test Loss: 0.0985
# Epoch [41/50], Train Loss: 0.0958, Test Loss: 0.0993
# Epoch [42/50], Train Loss: 0.0957, Test Loss: 0.0986
# Epoch [43/50], Train Loss: 0.0956, Test Loss: 0.0986
# Epoch [44/50], Train Loss: 0.0956, Test Loss: 0.0983
# Epoch [45/50], Train Loss: 0.0955, Test Loss: 0.0980
# Epoch [46/50], Train Loss: 0.0954, Test Loss: 0.0985
# Epoch [47/50], Train Loss: 0.0953, Test Loss: 0.0982
# Epoch [48/50], Train Loss: 0.0953, Test Loss: 0.0982
# Epoch [49/50], Train Loss: 0.0952, Test Loss: 0.0982
# Epoch [50/50], Train Loss: 0.0953, Test Loss: 0.0983
# Silhouette Score: -0.19179904460906982
# Cluster Purity: 0.183
# Normalized Mutual Information (NMI): 0.23406035754286517
# Silhouette Score: -0.15606243908405304
# Cluster Purity: 0.229
# Normalized Mutual Information (NMI): 0.09564892816852454
# Silhouette Score: 0.016800178214907646
# Cluster Purity: 0.431
# Normalized Mutual Information (NMI): 0.0867423708383881
# (Autoencoder(
#    (encoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (1): Dropout(p=0.1, inplace=False)
#      (2): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (3): Dropout(p=0.1, inplace=False)
#      (4): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (9): Dropout(p=0.1, inplace=False)
#      (10): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (11): Dropout(p=0.1, inplace=False)
#      (12): ResidualBlock(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#      )
#      (13): Dropout(p=0.1, inplace=False)
#      (14): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (15): Dropout(p=0.1, inplace=False)
#      (16): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (17): Dropout(p=0.1, inplace=False)
#    )
#    (fc1): Linear(in_features=8192, out_features=4, bias=True)
#    (fc2): Linear(in_features=4, out_features=8192, bias=True)
#    (decoder): Sequential(
#      (0): ResidualBlock(
#        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (1): Upsample(scale_factor=2.0, mode='nearest')
#      (2): Dropout(p=0.1, inplace=False)
#      (3): ResidualBlock(
#        (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (4): Upsample(scale_factor=2.0, mode='nearest')
#      (5): Dropout(p=0.1, inplace=False)
#      (6): ResidualBlock(
#        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (7): Dropout(p=0.1, inplace=False)
#      (8): ResidualBlock(
#        (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (shortcut): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#      )
#      (9): Upsample(scale_factor=2.0, mode='nearest')
#      (10): Dropout(p=0.1, inplace=False)
#      (11): ResidualBlock(
#        (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (relu): ReLU()
#        (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      )
#      (12): Dropout(p=0.1, inplace=False)
#      (13): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (14): Sigmoid()
#    )
#  ),
#  [0.22193531699169178,
#   0.14603841530914885,
#   0.1381784735110621,
#   0.13164513132061822,
#   0.127422423634571,
#   0.12422254755378911,
#   0.11972340386801253,
#   0.11703941461662896,
#   0.11495122570580187,
#   0.11328185356843967,
#   0.11163087165393769,
#   0.11078903901453216,
#   0.10989553312333628,
#   0.10800785328538273,
#   0.10817965315268062,
#   0.10538353315129066,
#   0.11030539851219129,
#   0.11068799694220478,
#   0.10791951984452744,
#   0.106368483314975,
#   0.10505504625293012,
#   0.10325792360420044,
#   0.1027385421787588,
#   0.10139439125268604,
#   0.10068670307961516,
#   0.09999021669974723,
#   0.0997849350777297,
#   0.09935312945479022,
#   0.09885869145440979,
#   0.0986911633406013,
#   0.09856261734288341,
#   0.09856428926031048,
#   0.09777709758415008,
#   0.09729382674248455,
#   0.09678525353868167,
#   0.0970755656734823,
#   0.09663231312609709,
#   0.09631263085019093,
#   0.09628990246131779,
#   0.0961047642694685,
#   0.09580722435737571,
#   0.0957222729921341,
#   0.09556931902330143,
#   0.0956364787234285,
#   0.09552016079473419,
#   0.09540778541336425,
#   0.0953427747772715,
#   0.09529933982049696,
#   0.09524738081632711,
#   0.09529696095484895],
#  [0.1605528775188658,
#   0.14458240816990534,
#   0.1375794435540835,
#   0.13397726759551062,
#   0.13027462422374694,
#   0.12928103631924068,
#   0.120876982098534,
#   0.12217029550718883,
#   0.11818854238778825,
#   0.12146883729904417,
#   0.11693216919425935,
#   0.11468896589108876,
#   0.11143776857190663,
#   0.10952697777085835,
#   0.10801461380389002,
#   0.10813992233976485,
#   0.1165704114569558,
#   0.11168481799818221,
#   0.10941883365786265,
#   0.10882713834917734,
#   0.1061134577861854,
#   0.10542930638979352,
#   0.10857112126217948,
#   0.10285753064921924,
#   0.10728871650875561,
#   0.10183443093583697,
#   0.10227918163651512,
#   0.102009612298201,
#   0.10225372501308956,
#   0.10130904845538594,
#   0.10045993316268163,
#   0.10219612173617833,
#   0.09981291208948408,
#   0.10014188124073876,
#   0.09878669105588443,
#   0.10174729089651789,
#   0.10027469523132794,
#   0.09998387506320364,
#   0.09841594756359145,
#   0.098525737249662,
#   0.0993356882698006,
#   0.09860861549774806,
#   0.09864718993268316,
#   0.09834182569904933,
#   0.09803665003606252,
#   0.0985409730956668,
#   0.09816826939109773,
#   0.09821094684894123,
#   0.09822377899572962,
#   0.09826632441272812])

# %%
train_model(embedding_size=8, dropout_rate=0.1)
# Out:
# Number of parameters: 1749035
# Epoch [1/50], Train Loss: 0.2206, Test Loss: 0.1483
# Epoch [2/50], Train Loss: 0.1427, Test Loss: 0.1412
# Epoch [3/50], Train Loss: 0.1319, Test Loss: 0.1209
# Epoch [4/50], Train Loss: 0.1170, Test Loss: 0.1119
# Epoch [5/50], Train Loss: 0.1113, Test Loss: 0.1104
# Epoch [6/50], Train Loss: 0.1069, Test Loss: 0.1067
# Epoch [7/50], Train Loss: 0.1039, Test Loss: 0.1022
# Epoch [8/50], Train Loss: 0.1016, Test Loss: 0.1032
# Epoch [9/50], Train Loss: 0.0987, Test Loss: 0.1015

# %%
train_model(embedding_size=16, dropout_rate=0.1)

# %%
train_model(embedding_size=32, dropout_rate=0.1)

# %%
train_model(embedding_size=64, dropout_rate=0.1)
